# %% [markdown]
# # Regresión simple

# %% [markdown]
# ## Teoría

# %% [markdown]
# ![Imagen](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Linear_regression.svg/1200px-Linear_regression.svg.png)

# %% [markdown]
# Mi nombre es Jhonier Rangel soy estadístico y estoy haciendo mi tesis de maestría en ciecnias estadística y deseo aprender IA

# %% [markdown]
# ![foto.png](attachment:ee8f4006-7575-4cc5-a9f1-7d0bd3f16a70.png)

# %% [markdown]
# Here is the simple linear regression formula in LaTeX format:
#
# $$y = \beta_0 + \beta_1 x + \varepsilon$$
#
# where:
#
# - $y$ is the dependent variable
# - $x$ is the independent variable
# - $\beta_0$ is the intercept
# - $\beta_1$ is the slope of the line
# - $\varepsilon$ is the error term

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
print(intercept,slope)
# Out:
# 103.10596026490066 -1.7512877115526118

# %% [markdown]
# # y evaluados en el modelo

# %%
print(mymodel)
# Out:
# [94.3495217071376, 90.84694628403238, 89.09565857247976, 90.84694628403238, 99.60338484179543, 73.33406916850626, 99.60338484179543, 87.34437086092716, 96.10080941869022, 83.84179543782193, 82.09050772626932, 87.34437086092716, 92.59823399558499]

# %% [markdown]
# # Refrencias

# %% [markdown]
# [Regresión](https://www.w3schools.com/python/python_ml_linear_regression.asp)

# %% [markdown]
# [click para jugar en colab](https://colab.research.google.com/drive/1STwRvHiu47QnoCEiPGdDWA8sIqa5muxb)
