# %% [markdown]
# <a href="https://colab.research.google.com/github/jrangelg/Artificial-intelligence/blob/main/Coeficiente.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 x<-rnorm(10000,3,1)

# %%
hist(x,col = 3, main = "Resistencia mecánica6")
# Out:
# Plot with title “Histogram of x”

# %%
 y<-5+4*x+rnorm(10000,0,2)

# %%
plot(x,y)
# Out:
# plot without title

# %%
cor(x,y)
# Out:
# [1] 0.8929036

# %%
x<-rnorm(100)
y<-x**2

# %%
plot(x,y)
# Out:
# plot without title

# %%
cor(x,y)
# Out:
# [1] 0.1522486

# %%
x<-rnorm(100)
y<-x**3

# %%
plot(x,y)
# Out:
# plot without title

# %%
cor(x,y,method = "spearman")
# Out:
# [1] 1

# %%
x<-c(x,3)
y<-c(y,200)

# %%
plot(x,y)
# Out:
# plot without title

# %%
cor(x,y)
# Out:
# [1] 0.4328756

# %%
cor(x,y,method = "spearman")
# Out:
# [1] 1

# %% [markdown]
# # Task
# Fit a linear regression model using `x` from cell `u85p05OR6wT_` as the independent variable and `y` from cell `zuelCVjiXsDI` as the dependent variable. Then, display a summary of the linear regression model to show coefficients, R-squared, and other statistical information. Finally, generate plots of residuals against fitted values, a Q-Q plot of residuals, and a histogram of residuals to assess the model's assumptions.

# %% [markdown]
# ## Fit Linear Model
#
# ### Subtask:
# Fit a linear regression model using x as the independent variable and y as the dependent variable, using the initial definitions of x and y from the notebook (cell u85p05OR6wT_ and zuelCVjiXsDI).

# %% [markdown]
# **Reasoning**:
# Fit a linear regression model in R using the previously defined 'x' as the independent variable and 'y' as the dependent variable, storing the result in 'linear_model'.

# %%
linear_model <- lm(y ~ x)
